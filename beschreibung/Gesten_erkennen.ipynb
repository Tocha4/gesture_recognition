# %% [markdown]
# # Live Gestenerkennung mit einer Webcam
# Um das trainierte Modell zu benutzen kann das Skript ```../03_Gesture_recognition.py``` benutzt werden. Dieses erzeugt die Live-Aufnahmen sowie einen Graphen, der die Wahrscheinlichkeiten der erkannten Gesten über die Zeit aufträgt. Die Gesten Null bis Sechs können als Buchstaben angesehenwerden. Es lässt sich für jeden Buchstaben ein Steuerungsbefehl programmieren. Außerdem ist es möglich mehrere Buchstaben zu kombinieren und so erhält man weitere Möglichkeiten Befehle zu programmieren.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('BbtzxUtnSDU', width=800)
